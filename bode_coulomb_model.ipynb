# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from functools import partial

# Define the system of first-order differential equations
# y is a vector [x, v], where y[0] = x and y[1] = v = x_dot
# t is the time

m = 1.4e-5
# d = 2e-3
d = 1e-3
# J = 1/6 * m * d**2
J = 1/12 * m * (2 * d**2)
# B = 0.5e-6
B = 1e-6
C = 3.22e-9 * 1.25
# wb = 50*2*np.pi

r = 0.75e-3
theta2_crit = 2 * np.pi * 0.1
F_dyn =  abs((C*80*2*np.pi - 1.2e-6)/r) / 1000
F_stat = F_dyn * 1.1

def wrap(theta_diff):
    return theta_diff - 2*np.pi * np.floor((theta_diff+np.pi)/np.pi/2)

vels = []
mag_mult = np.linspace(0.01,2,30)
v_means = []
step_outs = []
wbs=[]

print(f"F_dyn={F_dyn}, F_stat={F_stat}, theta2_crit={theta2_crit}")
omega_crit = 50 * 2 * np.pi

for j in range(1,90+10,10):
    wb = 2*np.pi * j
    print(j, end="\r")
    v_means = []
    vels = []
    for i in mag_mult:
        def model(t, y, B, wb, C, J):
            theta1, theta2 = y
            theta1d = theta2
            f_fric = F_dyn + (F_stat - F_dyn) * np.exp(-abs(theta2)/theta2_crit)
            theta2d = + ( np.sign(theta2)*f_fric + B*np.sin(wrap(wb*t - theta1)) - C * theta2)/J
            return [theta1d, theta2d]

        # Set the initial conditions
        theta1_0 = 0.0  # Initial position: x(0)
        theta2_0 = 0.0  # Initial velocity: x_dot(0)
        initial_conditions = [theta1_0, theta2_0]

        # Set the time interval to solve for
        t_span = [0, 0.2] # from t=0 to t=20
        t_eval = np.linspace(t_span[0], t_span[1], 1000) # points where solution is saved

        # Use the numerical solver
        # 'solve_ivp' stands for "solve initial value problem"
        solution = solve_ivp(
            fun=partial(model, B=B*i, wb=wb, C=C, J=J),
            t_span=t_span,
            y0=initial_conditions,
            t_eval=t_eval
        )

        # Extract the results
        t = solution.t
        x = solution.y[0]
        v = solution.y[1]
        v_mean = np.mean(v)
        v_means.append(v_mean)
        vels.append(v)

    b_fields = B*mag_mult

    # Plot the solution
    plt.figure(figsize=(10, 5))
    for idx, vl in enumerate(vels): plt.plot(t, vl, label=f"B={b_fields[idx]:.3g}")
    plt.title('Numerical Solution')
    plt.xlabel('Time [t]')
    plt.ylabel('Velocity[theta_dot(t)]')
    plt.grid(True)
    plt.legend()
    plt.show()

    # plt.figure()
    # plt.plot(b_fields, v_means)
    # plt.ylabel('Velocity[theta_dot(t)]')
    # plt.xlabel('B torque [Nm]')
    # plt.grid()

    step_out = b_fields[np.argmax(abs(np.diff(v_means)))+1]
    step_outs.append(step_out)
    wbs.append(wb)

    plt.figure()
    plt.plot(b_fields[:-1], np.diff(v_means))
    plt.ylabel('diff Velocity[theta_dot(t)]')
    plt.xlabel('B torque [Nm]')
    plt.grid()
    print(f"step out field {step_out} Nm")

fig,ax = plt.subplots(1,1)
ax.plot(np.array(wbs)/2/np.pi, step_outs)
ax.set_xlabel("drive freq [Hz]")
ax.set_ylabel("mag_torque [Nm]")
ax.set_title(f"step_out torque at each drive frequency")
ax.grid()
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# F_dyn=1.0975808918824352e-06, F_stat=1.2073389810706789e-06, theta2_crit=0.6283185307179586
# 1
# step out field 1.1079310344827585e-06 Nm
# 11
# step out field 8.334482758620689e-07 Nm
# 21
# step out field 5.589655172413793e-07 Nm
# 31
# step out field 3.531034482758621e-07 Nm
# 41
# step out field 7.862068965517241e-08 Nm
# 51
# step out field 2.1586206896551723e-07 Nm
# 61
# step out field 4.903448275862069e-07 Nm
# 71
# step out field 6.962068965517241e-07 Nm
# 81
# step out field 9.706896551724137e-07 Nm
# 91
# step out field 1.2451724137931034e-06 Nm
# /tmp/ipykernel_34373/3407444565.py:112: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
