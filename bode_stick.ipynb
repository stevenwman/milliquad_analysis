# %%
D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 D
#
# NameError: name 'D' is not defined

# %%
tau
# Out:
# 1e-05

# %%
import numpy as np
np.logspace(-1,-8,7)
# Out:
# array([1.00000000e-01, 6.81292069e-03, 4.64158883e-04, 3.16227766e-05,
#        2.15443469e-06, 1.46779927e-07, 1.00000000e-08])

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.integrate import solve_ivp
# from functools import partial

# # Define the system of first-order differential equations
# # y is a vector [x, v], where y[0] = x and y[1] = v = x_dot
# # t is the time

# m = 1.4e-5
# d = 2e-3
# J = 1/6 * m * d**2
# # B = 0.5e-6
# B = 1e-6
# C = 3.22e-9
# # wb = 50*2*np.pi
# # wb = 90*2*np.pi

# # tau = 1e-6
# r = 0.75e-3
# delta_trq = abs((C*80*2*np.pi - 1.2e-6)/r)
# # D = r * 0.05 / 180 * np.pi

# def wrap(theta_diff):
#     return theta_diff - 2*np.pi * np.floor((theta_diff+np.pi)/np.pi/2)


# for tau in np.logspace(-1,-8,7):
#     fig,ax = plt.subplots(1,1)
#     for deg in np.logspace(1,-2,5):
#         D = r * deg / 180 * np.pi
#         vels = []
#         mag_mult = np.linspace(0.1,2.5,10)
#         v_means = []
#         step_outs = []
#         wbs=[]
        
#         print(f"tau={tau}, D={D}")

#         for j in range(1,90+10,10):
#             wb = 2*np.pi * j
#             print(j, end="\r")
#             v_means = []
#             vels = []
#             for i in mag_mult:
#                 def model(t, y, B, wb, C, J):
#                     phi, theta1, theta2 = y
#                     phid = 1 - r * abs(theta2) * phi / D
#                     theta1d = theta2
#                     fric = delta_trq * r * (1 - np.exp(-phi/ tau))
#                     theta2d = (fric + B*np.sin(wrap(wb*t - theta1)) - C*theta2)/J
#                     return [phid, theta1d, theta2d]

#                 # Set the initial conditions
#                 phi_0 = 0.0
#                 theta1_0 = 0.0  # Initial position: x(0)
#                 theta2_0 = 0.0  # Initial velocity: x_dot(0)
#                 initial_conditions = [phi_0, theta1_0, theta2_0]

#                 # Set the time interval to solve for
#                 t_span = [0, 0.2] # from t=0 to t=20
#                 t_eval = np.linspace(t_span[0], t_span[1], 1000) # points where solution is saved

#                 # Use the numerical solver
#                 # 'solve_ivp' stands for "solve initial value problem"
#                 solution = solve_ivp(
#                     fun=partial(model, B=B*i, wb=wb, C=C, J=J),
#                     t_span=t_span,
#                     y0=initial_conditions,
#                     t_eval=t_eval
#                 )

#                 # Extract the results
#                 t = solution.t
#                 x = solution.y[0]
#                 v = solution.y[2]
#                 v_mean = np.mean(v)
#                 v_means.append(v_mean)
#                 vels.append(v)

#             b_fields = B*mag_mult

#             # # Plot the solution
#             # plt.figure(figsize=(10, 5))
#             # for idx, vl in enumerate(vels): plt.plot(t, vl, label=f"B={b_fields[idx]:.3g}")
#             # plt.title('Numerical Solution')
#             # plt.xlabel('Time [t]')
#             # plt.ylabel('Velocity[theta_dot(t)]')
#             # plt.grid(True)
#             # plt.legend()
#             # plt.show()

#             # plt.figure()
#             # plt.plot(b_fields, v_means)
#             # plt.ylabel('Velocity[theta_dot(t)]')
#             # plt.xlabel('B torque [Nm]')
#             # plt.grid()

#             step_out = b_fields[np.argmax(abs(np.diff(v_means)))]
#             step_outs.append(step_out)
#             wbs.append(wb)

#             # plt.figure()
#             # plt.plot(b_fields[:-1], np.diff(v_means))
#             # plt.ylabel('diff Velocity[theta_dot(t)]')
#             # plt.xlabel('B torque [Nm]')
#             # plt.grid()
#             # print(f"step out field {step_out} Nm")
    
#         ax.plot(np.array(wbs)/2/np.pi, step_outs, label=f"D={D}")
#         ax.set_xlabel("drive freq [Hz]")
#         ax.set_ylabel("mag_torque [Nm]")
#         ax.set_title(f"tau={tau:3g} step_out torque at each drive frequency")
#         ax.grid()
#         plt.tight_layout()
#         plt.legend()
#     plt.show()
# Out:
# tau=0.1, D=0.0001308996938995747
# tau=0.1, D=2.327762304420113e-05
# tau=0.1, D=4.139411777415042e-06
# tau=0.1, D=7.361030733449789e-07
# 91
# /tmp/ipykernel_448506/1711814308.py:50: RuntimeWarning: overflow encountered in exp
#   fric = delta_trq * r * (1 - np.exp(-phi/ tau))
# /home/steven/anaconda3/envs/bode312/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:109: RuntimeWarning: invalid value encountered in divide
#   return norm(self._estimate_error(K, h) / scale)
# tau=0.1, D=1.3089969389957473e-07
# 91
# tau=0.006812920690579608, D=0.0001308996938995747
# tau=0.006812920690579608, D=2.327762304420113e-05
# tau=0.006812920690579608, D=4.139411777415042e-06
# tau=0.006812920690579608, D=7.361030733449789e-07
# tau=0.006812920690579608, D=1.3089969389957473e-07
# 91
# tau=0.00046415888336127773, D=0.0001308996938995747
# tau=0.00046415888336127773, D=2.327762304420113e-05
# 51
# /home/steven/anaconda3/envs/bode312/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2791: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# tau=0.00046415888336127773, D=4.139411777415042e-06
# tau=0.00046415888336127773, D=7.361030733449789e-07
# tau=0.00046415888336127773, D=1.3089969389957473e-07
# 91
# tau=3.1622776601683795e-05, D=0.0001308996938995747
# 91
# /tmp/ipykernel_448506/1711814308.py:48: RuntimeWarning: overflow encountered in scalar multiply
#   phid = 1 - r * abs(theta2) * phi / D
# tau=3.1622776601683795e-05, D=2.327762304420113e-05
# 71
# /tmp/ipykernel_448506/1711814308.py:48: RuntimeWarning: overflow encountered in scalar divide
#   phid = 1 - r * abs(theta2) * phi / D
# 81
# /home/steven/anaconda3/envs/bode312/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:66: RuntimeWarning: invalid value encountered in dot
#   y_new = y + h * np.dot(K[:-1].T, B)
# /tmp/ipykernel_448506/1711814308.py:36: RuntimeWarning: invalid value encountered in scalar subtract
#   return theta_diff - 2*np.pi * np.floor((theta_diff+np.pi)/np.pi/2)
# /home/steven/anaconda3/envs/bode312/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:106: RuntimeWarning: invalid value encountered in dot
#   return np.dot(K.T, self.E) * h
# /home/steven/anaconda3/envs/bode312/lib/python3.12/site-packages/scipy/integrate/_ivp/rk.py:63: RuntimeWarning: invalid value encountered in dot
#   dy = np.dot(K[:s].T, a[:s]) * h
# tau=3.1622776601683795e-05, D=4.139411777415042e-06
# tau=3.1622776601683795e-05, D=7.361030733449789e-07
# tau=3.1622776601683795e-05, D=1.3089969389957473e-07
# 91
# tau=2.1544346900318822e-06, D=0.0001308996938995747
# tau=2.1544346900318822e-06, D=2.327762304420113e-05
# 71
# /tmp/ipykernel_448506/1711814308.py:51: RuntimeWarning: overflow encountered in scalar divide
#   theta2d = (fric + B*np.sin(wrap(wb*t - theta1)) - C*theta2)/J
# tau=2.1544346900318822e-06, D=4.139411777415042e-06
# tau=2.1544346900318822e-06, D=7.361030733449789e-07
# tau=2.1544346900318822e-06, D=1.3089969389957473e-07
# 91
# tau=1.4677992676220674e-07, D=0.0001308996938995747
# tau=1.4677992676220674e-07, D=2.327762304420113e-05
# tau=1.4677992676220674e-07, D=4.139411777415042e-06
# 61
# /tmp/ipykernel_448506/1711814308.py:50: RuntimeWarning: overflow encountered in scalar divide
#   fric = delta_trq * r * (1 - np.exp(-phi/ tau))
# tau=1.4677992676220674e-07, D=7.361030733449789e-07
# tau=1.4677992676220674e-07, D=1.3089969389957473e-07
# 91
# tau=1e-08, D=0.0001308996938995747
# tau=1e-08, D=2.327762304420113e-05
# tau=1e-08, D=4.139411777415042e-06
# tau=1e-08, D=7.361030733449789e-07
# tau=1e-08, D=1.3089969389957473e-07
# 91

# %%
fig = plt.figure()
plt.plot(np.array(wbs)/2/np.pi, step_outs)
plt.xlabel("drive freq [Hz]")
plt.ylabel("mag_torque [Nm]")
plt.title("step_out torque at each drive frequency")
plt.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from functools import partial

# Define the system of first-order differential equations
# y is a vector [x, v], where y[0] = x and y[1] = v = x_dot
# t is the time

m = 1.4e-5
d = 2e-3
J = 1/6 * m * d**2
# B = 0.5e-6
B = 1e-6
C = 3.22e-9
# wb = 50*2*np.pi
# wb = 90*2*np.pi

tau = 1e-5
r = 0.75e-3
delta_trq = abs((C*80*2*np.pi - 1.2e-6)/r) * 2
deg = 10
D = r * deg / 180 * np.pi

def wrap(theta_diff):
    return theta_diff - 2*np.pi * np.floor((theta_diff+np.pi)/np.pi/2)

vels = []
mag_mult = np.linspace(0.01,2,30)
v_means = []
step_outs = []
wbs=[]

print(f"tau={tau}, D={D}")

for j in range(1,90+10,10):
    wb = 2*np.pi * j
    print(j, end="\r")
    v_means = []
    vels = []
    for i in mag_mult:
        def model(t, y, B, wb, C, J):
            phi, theta1, theta2 = y
            phid = 1 - r * abs(theta2) * phi / D
            theta1d = theta2
            fric = delta_trq * r * (1 - np.exp(-abs(phi)/ tau))
            theta2d = (fric + B*np.sin(wrap(wb*t - theta1)) - C*theta2)/J
            return [phid, theta1d, theta2d]

        # Set the initial conditions
        phi_0 = 0.0
        theta1_0 = 0.0  # Initial position: x(0)
        theta2_0 = 0.0  # Initial velocity: x_dot(0)
        initial_conditions = [phi_0, theta1_0, theta2_0]

        # Set the time interval to solve for
        t_span = [0, 0.2] # from t=0 to t=20
        t_eval = np.linspace(t_span[0], t_span[1], 1000) # points where solution is saved

        # Use the numerical solver
        # 'solve_ivp' stands for "solve initial value problem"
        solution = solve_ivp(
            fun=partial(model, B=B*i, wb=wb, C=C, J=J),
            t_span=t_span,
            y0=initial_conditions,
            t_eval=t_eval
        )

        # Extract the results
        t = solution.t
        x = solution.y[0]
        v = solution.y[2]
        v_mean = np.mean(v)
        v_means.append(v_mean)
        vels.append(v)

    b_fields = B*mag_mult

    # Plot the solution
    plt.figure(figsize=(10, 5))
    for idx, vl in enumerate(vels): plt.plot(t, vl, label=f"B={b_fields[idx]:.3g}")
    plt.title('Numerical Solution')
    plt.xlabel('Time [t]')
    plt.ylabel('Velocity[theta_dot(t)]')
    plt.grid(True)
    plt.legend()
    plt.show()

    # plt.figure()
    # plt.plot(b_fields, v_means)
    # plt.ylabel('Velocity[theta_dot(t)]')
    # plt.xlabel('B torque [Nm]')
    # plt.grid()

    step_out = b_fields[np.argmax(abs(np.diff(v_means)))+1]
    step_outs.append(step_out)
    wbs.append(wb)

    plt.figure()
    plt.plot(b_fields[:-1], np.diff(v_means))
    plt.ylabel('diff Velocity[theta_dot(t)]')
    plt.xlabel('B torque [Nm]')
    plt.grid()
    print(f"step out field {step_out} Nm")

fig,ax = plt.subplots(1,1)
ax.plot(np.array(wbs)/2/np.pi, step_outs, label=f"D={D}")
ax.set_xlabel("drive freq [Hz]")
ax.set_ylabel("mag_torque [Nm]")
ax.set_title(f"tau={tau:3g} step_out torque at each drive frequency")
ax.grid()
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# tau=1e-05, D=0.0001308996938995747
# 1
# step out field 8.334482758620689e-07 Nm
# 11
# step out field 6.275862068965517e-07 Nm
# 21
# step out field 4.2172413793103444e-07 Nm
# 31
# step out field 2.1586206896551723e-07 Nm
# 41
# step out field 7.862068965517241e-08 Nm
# 51
# step out field 2.1586206896551723e-07 Nm
# 61
# step out field 4.2172413793103444e-07 Nm
# 71
# step out field 6.275862068965517e-07 Nm
# 81
# step out field 8.334482758620689e-07 Nm
# 91
# step out field 1.0393103448275861e-06 Nm
